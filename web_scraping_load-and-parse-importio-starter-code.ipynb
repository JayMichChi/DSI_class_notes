# %%
import urllib2
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(urllib2.urlopen('http://www.timeanddate.com/worldclock/astronomy.html?n=78').read())
for row in soup('table', {'class' : 'spad'})[0].tbody('tr'):
    tds = row('td')
    print tds[0].string, tds[1].string
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-d76996a77f01> in <module>()
#       1 soup = BeautifulSoup(urllib2.urlopen('http://www.timeanddate.com/worldclock/astronomy.html?n=78').read())
# ----> 2 for row in soup('table', {'class' : 'spad'})[0].tbody('tr'):
#       3     tds = row('td')
#       4     print tds[0].string, tds[1].string
#
# IndexError: list index out of range

# %%
soup = BeautifulSoup(urllib2.urlopen('http://www.timeanddate.com/worldclock/astronomy.html?n=78').read())

# %%
for row in soup('table', {'class' : 'spad'})[0].tbody('tr'):
    tds = row('td')
    print tds[0].string, tds[1].string
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-a19d46dfdca3> in <module>()
# ----> 1 for row in soup('table', {'class' : 'spad'})[0].tbody('tr'):
#       2     tds = row('td')
#       3     print tds[0].string, tds[1].string
#
# IndexError: list index out of range

# %%
for table in soup('table'):
    print table
    print '\n'
    
len(soup('table'))
# Out:
# <table class="va-m fw" id="lm-key"><tbody><tr id="lm-leg-0"><td><div class="c-key as-night"></div></td><td>Night</td><td class="tr">12:00 AM – 6:02 AM</td></tr><tr id="lm-leg-1"><td><div class="c-key as-astronomical-twilight"></div></td><td>Astro. Twilight</td><td class="tr">6:02 AM – 6:42 AM</td></tr><tr id="lm-leg-2"><td><div class="c-key as-nautical-twilight"></div></td><td>Nautical Twilight</td><td class="tr">6:42 AM – 7:23 AM</td></tr><tr id="lm-leg-3"><td><div class="c-key as-civil-twilight"></div></td><td>Civil Twilight</td><td class="tr">7:23 AM – 7:58 AM</td></tr><tr id="lm-leg-4"><td><div class="c-key as-daylight"></div></td><td>Daylight</td><td class="tr">7:58 AM – 6:21 PM</td></tr><tr id="lm-leg-5"><td><div class="c-key as-civil-twilight"></div></td><td>Civil Twilight</td><td class="tr">6:21 PM – 6:57 PM</td></tr><tr id="lm-leg-6"><td><div class="c-key as-nautical-twilight"></div></td><td>Nautical Twilight</td><td class="tr">6:57 PM – 7:37 PM</td></tr><tr id="lm-leg-7"><t
# ...

# %%
for row in soup('table', {'class' : 'va-m'}):
    print row, '\n'
# Out:
# <table class="va-m fw" id="lm-key"><tbody><tr id="lm-leg-0"><td><div class="c-key as-night"></div></td><td>Night</td><td class="tr">12:00 AM – 6:02 AM</td></tr><tr id="lm-leg-1"><td><div class="c-key as-astronomical-twilight"></div></td><td>Astro. Twilight</td><td class="tr">6:02 AM – 6:42 AM</td></tr><tr id="lm-leg-2"><td><div class="c-key as-nautical-twilight"></div></td><td>Nautical Twilight</td><td class="tr">6:42 AM – 7:23 AM</td></tr><tr id="lm-leg-3"><td><div class="c-key as-civil-twilight"></div></td><td>Civil Twilight</td><td class="tr">7:23 AM – 7:58 AM</td></tr><tr id="lm-leg-4"><td><div class="c-key as-daylight"></div></td><td>Daylight</td><td class="tr">7:58 AM – 6:21 PM</td></tr><tr id="lm-leg-5"><td><div class="c-key as-civil-twilight"></div></td><td>Civil Twilight</td><td class="tr">6:21 PM – 6:57 PM</td></tr><tr id="lm-leg-6"><td><div class="c-key as-nautical-twilight"></div></td><td>Nautical Twilight</td><td class="tr">6:57 PM – 7:37 PM</td></tr><tr id="lm-leg-7"><t
# ...

# %%
len(soup('table', {'class' : 'va-m'}))
# Out:
# 3

# %%
for row in soup('div', {'id' : 'qfacts'}):
    print row, '\n'
# Out:
# <div class="five columns" id="qfacts"><p><span class="four">Current Time: </span><span id="smct">Oct 17, 2016 at 9:00:35 PM</span></p><br/><p><span class="four">Sunrise Today: </span><span class="three">7:56 AM</span><span class="comp sa10" title="Map direction East">↑</span> 105° East<br/><span class="four">Sunset Today: </span><span class="three">6:24 PM</span><span class="comp sa22" title="Map direction West">↑</span> 255° West</p><br/><p><span class="four">Moonrise Today: </span><span class="three">7:35 PM</span><span class="comp sa6" title="Map direction East">↑</span> 69° East<br/><span class="four">Moonset Today: </span><span class="three">9:18 AM</span><span class="comp sa26" title="Map direction West">↑</span> 288° West</p><br/><p><span class="four">Daylight Hours: </span><span title="The current day is 10 hours, 27 minutes long which is 4m 5s shorter than yesterday.">10 hours, 27 minutes (-4m 5s)</span></p></div>

# %%
for row in soup('span', {'class' : 'four'}):
    print row, row.string, '\n'
# Out:
# <span class="four">Current Time: </span> Current Time:
#
# <span class="four">Sunrise Today: </span> Sunrise Today:
#
# <span class="four">Sunset Today: </span> Sunset Today:
#
# <span class="four">Moonrise Today: </span> Moonrise Today:
#
# <span class="four">Moonset Today: </span> Moonset Today:
#
# <span class="four">Daylight Hours: </span> Daylight Hours:

# %%
for row in soup('span', {'class' : 'three'}):
    print row, '\n'
# Out:
# <span class="three">7:56 AM</span>
#
# <span class="three">6:24 PM</span>
#
# <span class="three">7:35 PM</span>
#
# <span class="three">9:18 AM</span>

# %%
spans = []

for row in soup('div', {'id' : 'qfacts'}):
    for item in row('p'):
        for span in row('span'):
            spans.append(span)

# %%
spans = []

for row in soup('div', {'id' : 'qfacts'}):
    print row.prettify()
# Out:
# <div class="five columns" id="qfacts">
#  <p>
#   <span class="four">
#    Current Time:
#   </span>
#   <span id="smct">
#    Oct 17, 2016 at 9:00:35 PM
#   </span>
#  </p>
#  <br/>
#  <p>
#   <span class="four">
#    Sunrise Today:
#   </span>
#   <span class="three">
#    7:56 AM
#   </span>
#   <span class="comp sa10" title="Map direction East">
#    ↑
#   </span>
#   105° East
#   <br/>
#   <span class="four">
#    Sunset Today:
#   </span>
#   <span class="three">
#    6:24 PM
#   </span>
#   <span class="comp sa22" title="Map direction West">
#    ↑
#   </span>
#   255° West
#  </p>
#  <br/>
#  <p>
#   <span class="four">
#    Moonrise Today:
#   </span>
#   <span class="three">
#    7:35 PM
#   </span>
#   <span class="comp sa6" title="Map direction East">
#    ↑
#   </span>
#   69° East
#   <br/>
#   <span class="four">
#    Moonset Today:
#   </span>
#   <span class="three">
#    9:18 AM
#   </span>
#   <span class="comp sa26" title="Map direction West">
#    ↑
#   </span>
# ...

# %%
spans
# Out:
# [<span class="four">Current Time: </span>,
#  <span id="smct">Oct 17, 2016 at 9:00:35 PM</span>,
#  <span class="four">Sunrise Today: </span>,
#  <span class="three">7:56 AM</span>,
#  <span class="comp sa10" title="Map direction East">\u2191</span>,
#  <span class="four">Sunset Today: </span>,
#  <span class="three">6:24 PM</span>,
#  <span class="comp sa22" title="Map direction West">\u2191</span>,
#  <span class="four">Moonrise Today: </span>,
#  <span class="three">7:35 PM</span>,
#  <span class="comp sa6" title="Map direction East">\u2191</span>,
#  <span class="four">Moonset Today: </span>,
#  <span class="three">9:18 AM</span>,
#  <span class="comp sa26" title="Map direction West">\u2191</span>,
#  <span class="four">Daylight Hours: </span>,
#  <span title="The current day is 10 hours, 27 minutes long which is 4m 5s shorter than yesterday.">10 hours, 27 minutes (-4m 5s)</span>,
#  <span class="four">Current Time: </span>,
#  <span id="smct">Oct 17, 2016 at 9:00:35 PM</span>,
# ...

# %%
data_dictionary = {}

for x in range(0, len(spans), 2):
    data_dictionary[spans[x].string] = spans[x+1].string
    
data_dictionary
# Out:
# {u'6:24 PM': u'\u2191',
#  u'9:18 AM': u'\u2191',
#  u'Current Time: ': u'Oct 17, 2016 at 9:00:35 PM',
#  u'Daylight Hours: ': u'10 hours, 27 minutes (-4m 5s)',
#  u'Moonrise Today: ': u'7:35 PM',
#  u'Sunrise Today: ': u'7:56 AM',
#  u'\u2191': u'Moonset Today: '}

# %%
for cell in spans:
    print cell.string
# Out:
# Current Time:
# Oct 17, 2016 at 9:00:35 PM
# Sunrise Today:
# 7:56 AM
# ↑
# Sunset Today:
# 6:24 PM
# ↑
# Moonrise Today:
# 7:35 PM
# ↑
# Moonset Today:
# 9:18 AM
# ↑
# Daylight Hours:
# 10 hours, 27 minutes (-4m 5s)
# Current Time:
# Oct 17, 2016 at 9:00:35 PM
# Sunrise Today:
# 7:56 AM
# ↑
# Sunset Today:
# 6:24 PM
# ↑
# Moonrise Today:
# 7:35 PM
# ↑
# Moonset Today:
# 9:18 AM
# ↑
# Daylight Hours:
# 10 hours, 27 minutes (-4m 5s)
# Current Time:
# Oct 17, 2016 at 9:00:35 PM
# Sunrise Today:
# 7:56 AM
# ↑
# Sunset Today:
# 6:24 PM
# ↑
# Moonrise Today:
# 7:35 PM
# ↑
# Moonset Today:
# 9:18 AM
# ↑
# Daylight Hours:
# 10 hours, 27 minutes (-4m 5s)
# Current Time:
# Oct 17, 2016 at 9:00:35 PM
# Sunrise Today:
# 7:56 AM
# ↑
# Sunset Today:
# 6:24 PM
# ↑
# Moonrise Today:
# 7:35 PM
# ↑
# Moonset Today:
# 9:18 AM
# ↑
# Daylight Hours:
# 10 hours, 27 minutes (-4m 5s)

# %% [markdown]
# Load packages

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <!--
#
#
#
#
#
#
#
#
#
# scripts and programs that download content transparent to the user are not allowed without permission
#
#
#
#
#
# -->
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    Sun &amp; moon times today, Dublin, Ireland
#   </title>
#   <meta content="Calculations of sunrise and sunset, moonrise and moonset in Ireland – Dublin for the coming days. Generic astronomy calculator to calculate times for sunrise, sunset, moonrise, moonset for many cities, with daylight saving time and time zones taken in account." name="description"/>
#   <meta content="month, year, day, date, break of day, sunup, sunrise, first light, daylight, morning, sunset, sundown, evening, dusk, night, nightfall, twilight, end of day, hours, sunlight, moonlight, dark, darkness, midnight, midday, noon, elevation, longest, shortest, seasons, Ireland – Dublin," name="keywords"/>
# ...

# %%
# import all needed packages in first cell
import pandas as pd

# %% [markdown]
# Load the csv downloaded from import.io

# %%
# keep all functions in one cell, call them when you need them. 
def read_file(path): # path = dynamic input parameter
    return pd.read_csv(path)

# %%
# csv_file stored in the github assets folder,
# use the path below to read in dataset as dataFrame by using read_file(path) function
# call the dataframe reddit
path = '../../assets/data/importio_reddit.csv'

# %%
# get the data dictionary

# %% [markdown]
# Examine the loaded data with the head() function

# %%
# get first couple rows of the dataFrame

# %% [markdown]
# What are the names of the columns?

# %% [markdown]
# Print one of the columns. You will see it is a strange text format.

# %% [markdown]
# Re-encode the names of the columns to ASCII so that we can refer to them by name.
# [this code is provided since it is not obvious]

# %%
# our dataset is called reddit, but just put whatever you called yours in place of that.
newcols = [c.decode("utf-8").encode("ascii","ignore") for c in reddit.columns]
reddit.columns = newcols
print(reddit.columns)
print(reddit.columns[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-5900b6c11bab> in <module>()
#       1 # our dataset is called reddit, but just put whatever you called yours in place of that.
# ----> 2 newcols = [c.decode("utf-8").encode("ascii","ignore") for c in reddit.columns]
#       3 reddit.columns = newcols
#       4 print(reddit.columns)
#       5 print(reddit.columns[0])
#
# NameError: name 'reddit' is not defined

# %% [markdown]
# What are the correlations between [rank_number, score_number, submitted_value_numbers, bylinkmay_link_numbers]?

# %%
website = 'http://www.zillow.com/homes/for_sale/60625_rb/?fromHomePage=true&shouldFireSellPageImplicitClaimGA=false&fromHomePageTab=buy'

# %%
website_data = urllib2.urlopen(website).read()
print website_data
# Out:
# <!DOCTYPE html><html itemscope="" itemtype="http://schema.org/Organization" class="wf-loading no-js zsg-theme-modernized null" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:product="http://ogp.me/product#" >
# <head>
# ...

# %%
soup = BeautifulSoup(website_data)

# %%
print soup.prettify()
# Out:
# <!DOCTYPE html>
# <html class="wf-loading no-js zsg-theme-modernized null" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/product#">
#  <head>
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="http://fonts.googleapis.com" rel="dns-prefetch"/>
#   <link href="http://photos1.zillowstatic.com" rel="dns-prefetch"/>
#   <link href="http://photos2.zillowstatic.com" rel="dns-prefetch"/>
#   <link href="http://photos3.zillowstatic.com" rel="dns-prefetch"/>
#   <meta charset="utf-8"/>
#   <title>
#    60625 Real Estate - 60625 Homes For Sale  | Zillow
#   </title>
#   <meta content="Zillow has 307 homes for sale in 60625. View listing photos, review sales history, and use our detailed real estate filters to find the perfect place." name="description"/>
#   <meta content="Zillow, Inc." name="author"/>
# ...

# %%
for ptag in soup('p', {'class': 'zsg-photo-card-spec'})[0:3]:
    print ptag.parent.prettify(), '\n'
# Out:
# <div class="zsg-photo-card-caption">
#  <h4 class="zsg-photo-card-spec">
#   <span class="zsg-photo-card-status">
#    <span class="zsg-icon-for-sale">
#    </span>
#    Condo For Sale
#   </span>
#  </h4>
#  <p class="zsg-photo-card-spec">
#   <span class="zsg-photo-card-price">
#    $219,900
#   </span>
#   <span class="zsg-photo-card-info">
#    2 bds
#    <span class="interpunct">
#     ·
#    </span>
#    2 ba
#    <span class="interpunct">
#     ·
#    </span>
#    1,500 sqft
#   </span>
#  </p>
#  <p class="zsg-photo-card-spec">
#   <span class="zsg-photo-card-notification zsg-icon-arrow-menu-down">
#    $5,000&amp;nbsp(Oct 7)
#   </span>
#   <span class="interpunct">
#    ·
#   </span>
#   <span class="zsg-photo-card-address">
#    4914 N St Louis Ave # 2, Chicago, IL
#   </span>
#  </p>
#  <p class="zsg-photo-card-spec">
#   <span class="zsg-photo-card-broker-name">
#    Baird &amp; Warner
#   </span>
#  </p>
# </div>
#
#
# <div class="zsg-photo-card-caption">
# ...

# %% [markdown]
# ### Now we have one "divtag" per zillow card!

# %%
for divtag in soup('div', {'class': 'zsg-photo-card-caption'}):
    print divtag, '\n'
# Out:
# <div class="zsg-photo-card-caption"><h4 class="zsg-photo-card-spec"><span class="zsg-photo-card-status"><span class="zsg-icon-for-sale"></span>Condo For Sale</span></h4><p class="zsg-photo-card-spec"><span class="zsg-photo-card-price">$219,900</span><span class="zsg-photo-card-info">2 bds <span class="interpunct">·</span> 2 ba <span class="interpunct">·</span> 1,500 sqft</span></p><p class="zsg-photo-card-spec"><span class="zsg-photo-card-notification zsg-icon-arrow-menu-down">$5,000&amp;nbsp(Oct 7)</span><span class="interpunct">·</span><span class="zsg-photo-card-address">4914 N St Louis Ave # 2, Chicago, IL</span></p><p class="zsg-photo-card-spec"><span class="zsg-photo-card-broker-name">Baird &amp; Warner</span></p></div>
#
# ...

# %%
print soup('div', {'class': 'zsg-photo-card-caption'})[0].prettify()
# Out:
# <div class="zsg-photo-card-caption">
#  <h4 class="zsg-photo-card-spec">
#   <span class="zsg-photo-card-status">
#    <span class="zsg-icon-for-sale">
#    </span>
#    Condo For Sale
#   </span>
#  </h4>
#  <p class="zsg-photo-card-spec">
#   <span class="zsg-photo-card-price">
#    $219,900
#   </span>
#   <span class="zsg-photo-card-info">
#    2 bds
#    <span class="interpunct">
#     ·
#    </span>
#    2 ba
#    <span class="interpunct">
#     ·
#    </span>
#    1,500 sqft
#   </span>
#  </p>
#  <p class="zsg-photo-card-spec">
#   <span class="zsg-photo-card-notification zsg-icon-arrow-menu-down">
#    $5,000&amp;nbsp(Oct 7)
#   </span>
#   <span class="interpunct">
#    ·
#   </span>
#   <span class="zsg-photo-card-address">
#    4914 N St Louis Ave # 2, Chicago, IL
#   </span>
#  </p>
#  <p class="zsg-photo-card-spec">
#   <span class="zsg-photo-card-broker-name">
#    Baird &amp; Warner
#   </span>
#  </p>
# </div>

# %%
for divtag in soup('div', {'class': 'zsg-photo-card-caption'}):
    for house_price in divtag('span', {'class': 'zsg-photo-card-price'}):
        print 'Here is a house price %s' % house_price.string
# Out:
# Here is a house price $219,900
# Here is a house price $319,000
# Here is a house price $314,900
# Here is a house price $259,000
# Here is a house price $219,000
# Here is a house price $149,900
# Here is a house price $199,900
# Here is a house price $279,999
# Here is a house price $154,000
# Here is a house price $79,000
# Here is a house price $450,000
# Here is a house price $499,000
# Here is a house price $255,000
# Here is a house price $100,000
# Here is a house price $1,200,000
# Here is a house price $429,000
# Here is a house price $179,900
# Here is a house price $339,900
# Here is a house price $299,000
# Here is a house price $700,000
# Here is a house price $619,000
# Here is a house price $2,299,000
# Here is a house price $334,900
# Here is a house price $199,900
# Here is a house price $350,000
# Here is a house price $560,000

# %%
for divtag in soup('div', {'class': 'zsg-photo-card-caption'}):
    for house_price in divtag('span', {'class': 'zsg-photo-card-price'}):
        print house_price, house_price.string
# Out:
# <span class="zsg-photo-card-price">$219,900</span> $219,900
# <span class="zsg-photo-card-price">$319,000</span> $319,000
# <span class="zsg-photo-card-price">$314,900</span> $314,900
# <span class="zsg-photo-card-price">$259,000</span> $259,000
# <span class="zsg-photo-card-price">$219,000</span> $219,000
# <span class="zsg-photo-card-price">$149,900</span> $149,900
# <span class="zsg-photo-card-price">$199,900</span> $199,900
# <span class="zsg-photo-card-price">$279,999</span> $279,999
# <span class="zsg-photo-card-price">$154,000</span> $154,000
# <span class="zsg-photo-card-price">$79,000</span> $79,000
# <span class="zsg-photo-card-price">$450,000</span> $450,000
# <span class="zsg-photo-card-price">$499,000</span> $499,000
# <span class="zsg-photo-card-price">$255,000</span> $255,000
# <span class="zsg-photo-card-price">$100,000</span> $100,000
# <span class="zsg-photo-card-price">$1,200,000</span> $1,200,000
# <span class="zsg-photo-card-price">$429,000</span> $429,000
# ...

# %%
data = {}

counter = 0

for divtag in soup('div', {'class': 'zsg-photo-card-caption'}):
    data[counter] = {}
    for house_price in divtag('span', {'class': 'zsg-photo-card-price'}):
        data[counter]['price'] = house_price.string
    counter += 1
    
data
# Out:
# {0: {'price': u'$219,900'},
#  1: {'price': u'$319,000'},
#  2: {'price': u'$314,900'},
#  3: {'price': u'$259,000'},
#  4: {'price': u'$219,000'},
#  5: {'price': u'$149,900'},
#  6: {'price': u'$199,900'},
#  7: {'price': u'$279,999'},
#  8: {'price': u'$154,000'},
#  9: {'price': u'$79,000'},
#  10: {'price': u'$450,000'},
#  11: {'price': u'$499,000'},
#  12: {'price': u'$255,000'},
#  13: {'price': u'$100,000'},
#  14: {'price': u'$1,200,000'},
#  15: {'price': u'$429,000'},
#  16: {'price': u'$179,900'},
#  17: {'price': u'$339,900'},
#  18: {'price': u'$299,000'},
#  19: {'price': u'$700,000'},
#  20: {'price': u'$619,000'},
#  21: {'price': u'$2,299,000'},
#  22: {'price': u'$334,900'},
#  23: {'price': u'$199,900'},
#  24: {'price': u'$350,000'},
#  25: {'price': u'$560,000'}}

# %%
data = {}

counter = 0

for divtag in soup('div', {'class': 'zsg-photo-card-caption'}):
    data[counter] = {}
    for house_price in divtag('span', {'class': 'zsg-photo-card-price'}):
        data[counter]['price'] = house_price.string
    for address in divtag('span', {'class': 'zsg-photo-card-address'}):
        data[counter]['address'] = address.string
    counter += 1
    
data
# Out:
# {0: {'address': u'4914 N St Louis Ave # 2, Chicago, IL', 'price': u'$219,900'},
#  1: {'address': u'4960 N Western Ave APT GS, Chicago, IL',
#   'price': u'$319,000'},
#  2: {'address': u'4919 N Lincoln Ave APT 1, Chicago, IL',
#   'price': u'$314,900'},
#  3: {'address': u'5588 N Lincoln Ave APT 402, Chicago, IL',
#   'price': u'$259,000'},
#  4: {'address': u'4943 N Kimball Ave # 1, Chicago, IL', 'price': u'$219,000'},
#  5: {'address': u'2427 W Farragut Ave, Chicago, IL', 'price': u'$149,900'},
#  6: {'address': u'2839 W Lawrence Ave APT 2D, Chicago, IL',
#   'price': u'$199,900'},
#  7: {'address': u'5034 N Saint Louis Ave, Chicago, IL', 'price': u'$279,999'},
#  8: {'address': u'3052 W Sunnyside Ave # 2, Chicago, IL',
#   'price': u'$154,000'},
#  9: {'address': u'5241 N Rockwell St APT BS, Chicago, IL',
#   'price': u'$79,000'},
#  10: {'address': u'2200 W Berwyn Ave, Chicago, IL', 'price': u'$450,000'},
# ...

# %%
data = {}

counter = 0

for divtag in soup('div', {'class': 'zsg-photo-card-caption'}):
    data[counter] = {}
    for house_price in divtag('span', {'class': 'zsg-photo-card-price'}):
        data[counter]['price'] = house_price.string
    for address in divtag('span', {'class': 'zsg-photo-card-address'}):
        data[counter]['address'] = address.string
    for broker in divtag('span', {'class': 'zsg-photo-card-broker-name'}):
        data[counter]['broker'] = broker.string
    counter += 1
    
data
# Out:
# {0: {'address': u'4914 N St Louis Ave # 2, Chicago, IL',
#   'broker': u'Baird & Warner',
#   'price': u'$219,900'},
#  1: {'address': u'4960 N Western Ave APT GS, Chicago, IL',
#   'broker': u'Berkshire Hathaway HomeServices KoenigRubloff Realty Group',
#   'price': u'$319,000'},
#  2: {'address': u'4919 N Lincoln Ave APT 1, Chicago, IL',
#   'broker': u'Conlon: A Real Estate Company',
#   'price': u'$314,900'},
#  3: {'address': u'5588 N Lincoln Ave APT 402, Chicago, IL',
#   'price': u'$259,000'},
#  4: {'address': u'4943 N Kimball Ave # 1, Chicago, IL', 'price': u'$219,000'},
#  5: {'address': u'2427 W Farragut Ave, Chicago, IL', 'price': u'$149,900'},
#  6: {'address': u'2839 W Lawrence Ave APT 2D, Chicago, IL',
#   'broker': u'Berkshire Hathaway HomeServices KoenigRubloff Realty Group',
#   'price': u'$199,900'},
#  7: {'address': u'5034 N Saint Louis Ave, Chicago, IL', 'price': u'$279,999'},
#  8: {'address': u'3052 W Sunnyside Ave # 2, Chicago, IL',
# ...

# %%
data = {}

counter = 0

for divtag in soup('div', {'class': 'zsg-photo-card-caption'}):
    data[counter] = {}
    for house_price in divtag('span', {'class': 'zsg-photo-card-price'}):
        data[counter]['price'] = house_price.string
    for address in divtag('span', {'class': 'zsg-photo-card-address'}):
        data[counter]['address'] = address.string
    for broker in divtag('span', {'class': 'zsg-photo-card-broker-name'}):
        data[counter]['broker'] = broker.string
    for house_info in divtag('span', {'class': 'zsg-photo-card-info'}):
        data[counter]['house_info'] = house_info.get_text()
    counter += 1
    
data
# Out:
# {0: {'address': u'4914 N St Louis Ave # 2, Chicago, IL',
#   'broker': u'Baird & Warner',
#   'house_info': u'2 bds \xb7 2 ba \xb7 1,500 sqft',
#   'price': u'$219,900'},
#  1: {'address': u'4960 N Western Ave APT GS, Chicago, IL',
#   'broker': u'Berkshire Hathaway HomeServices KoenigRubloff Realty Group',
#   'house_info': u'2 bds \xb7 2 ba \xb7 1,600 sqft',
#   'price': u'$319,000'},
#  2: {'address': u'4919 N Lincoln Ave APT 1, Chicago, IL',
#   'broker': u'Conlon: A Real Estate Company',
#   'house_info': u'2 bds \xb7 2 ba \xb7 1,380 sqft',
#   'price': u'$314,900'},
#  3: {'address': u'5588 N Lincoln Ave APT 402, Chicago, IL',
#   'house_info': u'2 bds \xb7 2 ba \xb7 1,259 sqft',
#   'price': u'$259,000'},
#  4: {'address': u'4943 N Kimball Ave # 1, Chicago, IL',
#   'house_info': u'3 bds \xb7 2 ba \xb7 1,300 sqft',
#   'price': u'$219,000'},
#  5: {'address': u'2427 W Farragut Ave, Chicago, IL',
#   'house_info': u'2 bds \xb7 1 ba \xb7 -- sqft',
#   'price': u'$149,900'},
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(data).T

# %%
df.head()
# Out:
#                                    address  \
# 0     4914 N St Louis Ave # 2, Chicago, IL
# 1   4960 N Western Ave APT GS, Chicago, IL
# 2    4919 N Lincoln Ave APT 1, Chicago, IL
# 3  5588 N Lincoln Ave APT 402, Chicago, IL
# 4      4943 N Kimball Ave # 1, Chicago, IL
#
#                                               broker  \
# 0                                     Baird & Warner
# 1  Berkshire Hathaway HomeServices KoenigRubloff ...
# 2                      Conlon: A Real Estate Company
# 3                                                NaN
# 4                                                NaN
#
#                   house_info     price
# 0  2 bds · 2 ba · 1,500 sqft  $219,900
# 1  2 bds · 2 ba · 1,600 sqft  $319,000
# 2  2 bds · 2 ba · 1,380 sqft  $314,900
# 3  2 bds · 2 ba · 1,259 sqft  $259,000
# 4  3 bds · 2 ba · 1,300 sqft  $219,000

# %%
df['bedrooms'] = df['house_info'].apply(lambda x: x.split(u'\xb7')[0])
df['bathrooms'] = df['house_info'].apply(lambda x: x.split(u'\xb7')[1])
df['square feet'] = df['house_info'].apply(lambda x: x.split(u'\xb7')[2])

# %%
df.loc[0, 'house_info'] # Here's where we figured out where to split
# Out:
# u'2 bds \xb7 2 ba \xb7 1,600 sqft'

# %%
df.head()
# Out:
#                                    address  \
# 0   4960 N Western Ave APT GS, Chicago, IL
# 1     4914 N St Louis Ave # 2, Chicago, IL
# 2    4919 N Lincoln Ave APT 1, Chicago, IL
# 3  5588 N Lincoln Ave APT 402, Chicago, IL
# 4  2839 W Lawrence Ave APT 2D, Chicago, IL
#
#                                               broker  \
# 0  Berkshire Hathaway HomeServices KoenigRubloff ...
# 1                                     Baird & Warner
# 2                      Conlon: A Real Estate Company
# 3                                                NaN
# 4  Berkshire Hathaway HomeServices KoenigRubloff ...
#
#                   house_info     price bedrooms bathrooms  square feet
# 0  2 bds · 2 ba · 1,600 sqft  $319,000   2 bds      2 ba    1,600 sqft
# 1  2 bds · 2 ba · 1,500 sqft  $219,900   2 bds      2 ba    1,500 sqft
# 2  2 bds · 2 ba · 1,380 sqft  $314,900   2 bds      2 ba    1,380 sqft
# 3  2 bds · 2 ba · 1,259 sqft  $259,000   2 bds      2 ba    1,259 sqft
# ...

# %%
df['price_numeric'] = df['price'].apply(lambda x: ''.join(ch for ch in x if ch.isdigit()))

# %%
price_one = '$199,900'

print ''.join([ch for ch in price_one if ch.isdigit()])
# Out:
# 199900

# %%
df.head()
# Out:
#                                    address  \
# 0   4960 N Western Ave APT GS, Chicago, IL
# 1     4914 N St Louis Ave # 2, Chicago, IL
# 2    4919 N Lincoln Ave APT 1, Chicago, IL
# 3  5588 N Lincoln Ave APT 402, Chicago, IL
# 4  2839 W Lawrence Ave APT 2D, Chicago, IL
#
#                                               broker  \
# 0  Berkshire Hathaway HomeServices KoenigRubloff ...
# 1                                     Baird & Warner
# 2                      Conlon: A Real Estate Company
# 3                                                NaN
# 4  Berkshire Hathaway HomeServices KoenigRubloff ...
#
#                   house_info     price bedrooms bathrooms  square feet  \
# 0  2 bds · 2 ba · 1,600 sqft  $319,000   2 bds      2 ba    1,600 sqft
# 1  2 bds · 2 ba · 1,500 sqft  $219,900   2 bds      2 ba    1,500 sqft
# 2  2 bds · 2 ba · 1,380 sqft  $314,900   2 bds      2 ba    1,380 sqft
# 3  2 bds · 2 ba · 1,259 sqft  $259,000   2 bds      2 ba    1,259 sqft
# ...

# %%
for column in ['bedrooms', 'bathrooms', 'square feet', 'price']:
    df[column+'_numeric'] = df[column].apply(lambda x: ''.join(ch for ch in x if ch.isdigit()))

# %%
import numpy as np
df['square feet_numeric'] = df['square feet_numeric'].apply(lambda x: np.nan if x == '' else x)

# %%
df[(df['square feet'] == '')] # this will show stuff before the lambda above!
# Out:
# Empty DataFrame
# Columns: [address, broker, house_info, price, bedrooms, bathrooms, square feet, bedrooms_numeric, bathrooms_numeric, square feet_numeric, price_numeric]
# Index: []

# %%
df.dtypes
# Out:
# address                object
# broker                 object
# house_info             object
# price                  object
# bedrooms               object
# bathrooms              object
# square feet            object
# bedrooms_numeric       object
# bathrooms_numeric      object
# square feet_numeric    object
# price_numeric          object
# dtype: object

# %%
for column in ['bedrooms', 'bathrooms', 'square feet', 'price']:
    df[column+'_numeric'] = df[column+'_numeric'].astype(float)

# %%
df[['bedrooms_numeric', 'bathrooms_numeric', 'square feet_numeric', 'price_numeric']].corr()
# Out:
#                      bedrooms_numeric  bathrooms_numeric  square feet_numeric  \
# bedrooms_numeric             1.000000           0.736289             0.885964
# bathrooms_numeric            0.736289           1.000000             0.867886
# square feet_numeric          0.885964           0.867886             1.000000
# price_numeric                0.753141           0.882003             0.920634
#
#                      price_numeric
# bedrooms_numeric          0.753141
# bathrooms_numeric         0.882003
# square feet_numeric       0.920634
# price_numeric             1.000000

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.heatmap(df[['bedrooms_numeric', 'bathrooms_numeric', 'square feet_numeric', 'price_numeric']].corr())
